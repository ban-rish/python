# %% [markdown]
# # we will create a file with inventory as follows -
# 1. Serial Number
# 2. product Name
# 3. Price
# 4. Quantity

# %%
fd = open("inventory.txt","r")
txt = fd.read()
fd.close()

txt
print(txt)
print("*"*50)

txt.split("\n")
txt
print(txt)
# Out:
# 1,Beans,200,100
# 2,Arhar Pulses,100,100
# 3,Flour,50,500
# 4,Rice,50,500
# **************************************************
# 1,Beans,200,100
# 2,Arhar Pulses,100,100
# 3,Flour,50,500
# 4,Rice,50,500

# %%
txt
# Out:
# '1,Beans,200,100\n2,Arhar Pulses,100,100\n3,Flour,50,500\n4,Rice,50,500'

# %%
products = txt.split("\n")

# %%
products
# Out:
# ['1,Beans,200,100',
#  '2,Arhar Pulses,100,100',
#  '3,Flour,50,500',
#  '4,Rice,50,500']

# %%
ui_input_id = input("Enter Product ID: ")
for product in products:
    if product.split(',')[0] == ui_input:
        product_details = product.split(',')
        print(product_details)
        ui_input_quantity = int(input("Enter Quantity : "))
        money = ui_input_quantity*int(product_details[2])
        print("Please Pay ",money)
        product_details[3] = str(int(product_details[3])-ui_input_quantity)
        print(product_details)
# Out:
# Enter Product ID:  3
# ['2', 'Arhar Pulses', '100', '100']
# Enter Quantity :  23
# Please Pay  2300
# ['2', 'Arhar Pulses', '100', '77']

# %%
for product in products:
    print(product)
    print(type(product))
    print(product.split(','))
# Out:
# 1,Beans,200,100
# <class 'str'>
# ['1', 'Beans', '200', '100']
# 2,Arhar Pulses,100,100
# <class 'str'>
# ['2', 'Arhar Pulses', '100', '100']
# 3,Flour,50,500
# <class 'str'>
# ['3', 'Flour', '50', '500']
# 4,Rice,50,500
# <class 'str'>
# ['4', 'Rice', '50', '500']
