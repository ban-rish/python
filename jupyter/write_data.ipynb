# %%
f2 = open("Employees.txt", "r") 
lst = [] 
for i in range(3):
    name = input("Enter the name of the employee: ")
    lst.append(name + '\n') 
	
f2.writelines(lst) 
print(lst)
f2.close() 
print("Data is written into the file.")
# Out:
# Enter the name of the employee:  e1
# Enter the name of the employee:  m1
# Enter the name of the employee:  s1
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[2], line 7
#       4     name = input("Enter the name of the employee: ")
#       5     lst.append(name + '\n')
# ----> 7 f2.writelines(lst)
#       8 print(lst)
#       9 f2.close()
#
# UnsupportedOperation: not writable
